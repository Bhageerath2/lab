# %%
# !git clone https://github.com/Bhageerath1/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 1355, done.
# remote: Counting objects: 100% (1355/1355), done.
# remote: Compressing objects: 100% (452/452), done.
# remote: Total 1355 (delta 902), reused 1355 (delta 902), pack-reused 0
# Receiving objects: 100% (1355/1355), 5.27 MiB | 14.98 MiB/s, done.
# Resolving deltas: 100% (902/902), done.

# %%
# !mkdir ~/.kaggle

# %%
! pip install -q kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 1.05G/1.06G [00:07<00:00, 231MB/s]
# 100% 1.06G/1.06G [00:07<00:00, 151MB/s]

# %%
import zipfile

# %%
with zipfile.ZipFile("/content/dogs-vs-cats.zip",'r') as zip_ref:
    zip_ref.extractall("/content")
